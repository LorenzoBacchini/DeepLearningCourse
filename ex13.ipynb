# %% [markdown]
# # Autoencoder
# Here we will code an autoencoder for denoising MNIST digits.

# %%
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

from res.plot_lib import plot_data, plot_data_np, plot_model, set_default
set_default()

# %%
# Load MNIST dataset

# TRAIN dataset
# Pytorch already has some datasets available for downlaod
train_dataset = datasets.MNIST('../data', train=True, download=True, 
                # transforms that we want to apply when iterating the dataset
                   transform=transforms.ToTensor())

# The datasoar will iterate through the dataset and load the data in memory
train_loader = torch.utils.data.DataLoader(
                        train_dataset,
                        batch_size=64, shuffle=True)

# TEST dataset
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, 
                   transform=transforms.ToTensor()),
                    batch_size=1000, shuffle=True)

# %%
print(len(train_dataset), len(train_loader))
# Out:
# 60000 938

# %%
# show some images
to_pil = transforms.ToPILImage()
plt.figure(figsize=(16, 6))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    image, _ = train_loader.dataset.__getitem__(i) # load one image
    plt.imshow(to_pil(image))
    plt.axis('off')

# %%
# Add noise to MNIST digits
noise_factor = 0.2

plt.figure(figsize=(16, 6))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    # define noise
    noise = torch.randn(1,28,28)
    
    image, _ = train_loader.dataset.__getitem__(i) # load one image
    
    image = (image + noise*noise_factor)
    imge = image.clamp_(0, 1)
    plt.imshow(to_pil(image))
    plt.axis('off')

# %%
# set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# Let's define our AE for denoising

# define the NN architecture
class AE_Denoiser(nn.Module):
    def __init__(self, latent_size = 64):
        super(AE_Denoiser, self).__init__()
        
        self.latent_size = latent_size
        
        ## encoder ##
        # x.size() = bs, 1, 28, 28 -> bs, latent_size
        self.Encoder = nn.Sequential(nn.Conv2d(1, 16, 4, stride = 2, padding=1), #16x14x14   [(W−K+2P)/S]+1
                                        nn.ReLU(),
                                        nn.Conv2d(16, 32, 4, stride = 2, padding=1), #32x7x7
                                        nn.ReLU(),
                                        nn.Conv2d(32, 64, 3, stride = 2, padding=1), #64x4x4
                                        nn.ReLU(),
                                        nn.Conv2d(64, self.latent_size, 4, stride = 1, padding=0), #64x1x1
                                        nn.ReLU(), 
                                        nn.Flatten())  #latent_size
        
        ## decoder ##
        # x.size() = bs, latent_size, 1, 1 -> bs, 1, 28, 28
        self.Decoder = nn.Sequential(nn.ConvTranspose2d( self.latent_size, 64, 4, 1, 0), #4x4  (W - 1)S -2P + (K - 1) + 1
                                    nn.ReLU(),
                                    nn.ConvTranspose2d( 64, 32, 3, 2, 1), #7x7
                                    nn.ReLU(),
                                    nn.ConvTranspose2d( 32, 16, 4, 2, 1), #14x14
                                    nn.ReLU(),
                                    nn.ConvTranspose2d( 16, 1, 4, 2, 1), #28x28
                                    nn.Sigmoid())


    def forward(self, x):
        ## encode ##
        latent = self.Encoder(x)  # compressed representation
        
        ## decode ##
        x = self.Decoder(latent.view(x.size(0),self.latent_size,1,1))
        
        return x, latent

    
ae = AE_Denoiser().to(device)
print(ae)
# Out:
# AE_Denoiser(
#   (Encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(16, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(64, 64, kernel_size=(4, 4), stride=(1, 1))
#     (7): ReLU()
#     (8): Flatten(start_dim=1, end_dim=-1)
#   )
#   (Decoder): Sequential(
#     (0): ConvTranspose2d(64, 64, kernel_size=(4, 4), stride=(1, 1))
#     (1): ReLU()
#     (2): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): ReLU()
#     (4): ConvTranspose2d(32, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (5): ReLU()
#     (6): ConvTranspose2d(16, 1, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (7): Sigmoid()
#   )
# )

# %%
# define Optimizer and Loss
optimizer = torch.optim.Adam(ae.parameters(), lr=0.001)

# as loss lets use MSE
mse_loss = nn.MSELoss()

# %%
# TRAIN!!!

ae.train()

for epoch in range(3):
    for batch_idx, (data, target) in enumerate(train_loader):
        # send to device
        data = data.to(device)
        
        # add noise pixels
        noise = torch.randn(data.size(0),1,28,28).to(device)
        noise_data = (data + noise*noise_factor).clamp_(0, 1)
        
        optimizer.zero_grad()
        output, latent = ae(noise_data)
        # loss between the output of AE and original data withoud noise
        loss = mse_loss(output, data)
        loss.backward()
        optimizer.step()
        if batch_idx % 200 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
    
    torch.save(ae.state_dict(), "./res/ae.pth")
# Out:
# Train Epoch: 0 [0/60000 (0%)]	Loss: 0.212375
# Train Epoch: 0 [12800/60000 (21%)]	Loss: 0.060318
# Train Epoch: 0 [25600/60000 (43%)]	Loss: 0.040752
# Train Epoch: 0 [38400/60000 (64%)]	Loss: 0.026627
# Train Epoch: 0 [51200/60000 (85%)]	Loss: 0.022291
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.016834
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.016651
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.015187
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.013659
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.012832
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.013854
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.011461
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.011210
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.009688
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.008988

# %%
# TEST
image, target = next(iter(test_loader)) # load one batch
image = image.to(device)
noise = torch.randn(image.size(0),1,28,28).to(device)
noise_image = (image + noise*noise_factor).clamp_(0, 1)

ae.eval()
with torch.no_grad():
    denoised_out, latent = ae(noise_image)

# %%
image_grid = torchvision.utils.make_grid(image[:8])
plt.imshow(to_pil(image_grid))
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(241.5), np.float64(31.5), np.float64(-0.5))

# %%
image_grid = torchvision.utils.make_grid(noise_image[:8])
plt.imshow(to_pil(image_grid))
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(241.5), np.float64(31.5), np.float64(-0.5))

# %%
image_grid = torchvision.utils.make_grid(denoised_out[:8])
plt.imshow(to_pil(image_grid))
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(241.5), np.float64(31.5), np.float64(-0.5))

# %%
print(latent.size())
# Out:
# torch.Size([1000, 64])

# %% [markdown]
# ### T-SNE
# t-SNE is a tool to visualize high-dimensional data:
# https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html
#
# We just need to specify to how many component we want to reduce our high dimentional space. In this case we want to pass from a latent code of dimension <code>latent_size</code> to a latent code of dimension 2.

# %%
# Let's visualize latent space
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2).fit_transform(latent.detach().cpu().numpy())

# %%
print(tsne.shape, target.shape)
# Out:
# (1000, 2) torch.Size([1000])

# %%
# plot
# scale and move the coordinates so they fit [-1; 1] range
def scale_to_01_range(x):
    # compute the distribution range
    value_range = (np.max(x) - np.min(x))

    # move the distribution so that it starts from zero
    # by extracting the minimal value from all its values
    starts_from_zero = x - np.min(x)

    # make the distribution fit [-1; 1] by dividing by its range
    return 2*(starts_from_zero / value_range) - 1

# extract x and y coordinates representing the positions of the images on T-SNE plot
tx = tsne[:, 0]
ty = tsne[:, 1]

tx = scale_to_01_range(tx)
ty = scale_to_01_range(ty)

tsne[:, 0] = tx
tsne[:, 1] = ty

plot_data_np(tsne, target.numpy(), legend = True)

# %%
tsne_3d = TSNE(n_components=3).fit_transform(latent.detach().cpu().numpy())

# %%
# extract x and y coordinates representing the positions of the images on T-SNE plot
tx = tsne_3d[:, 0]
ty = tsne_3d[:, 1]
tz = tsne_3d[:, 2]

tx = scale_to_01_range(tx)
ty = scale_to_01_range(ty)
tz = scale_to_01_range(tz)

tsne_3d[:, 0] = tx
tsne_3d[:, 1] = ty
tsne_3d[:, 2] = tz

fig = plt.figure()
ax = plt.axes(projection='3d')
scatter = ax.scatter3D(tsne_3d[:,0], tsne_3d[:,1], tsne_3d[:,2], c=target.numpy())
plt.legend(*scatter.legend_elements(), title="Classes")

# %%
# Ex1: Train Autoencoder for super resolution: upsampling MNIST images from 7x7 (or 14x14) to 28x28
# SUGGESTION: use torch.nn.functional.interpolate to resize input images  
# Let's define our AE for denoising

# %%
# downsampling test

image = next(iter(train_loader))
print(image[0].shape)
imm = torch.nn.functional.interpolate(image[0], size=[7,7], mode='bilinear', align_corners=False, antialias=True)
print(imm[0].shape)
fig, ax = plt.subplots(1, 2, figsize=(6, 3))

# prima immagine
ax[0].imshow(to_pil(image[0][0]), cmap="gray")
ax[0].set_title("Immagine 1")
ax[0].axis("off")

# seconda immagine
ax[1].imshow(to_pil(imm[0]), cmap="gray")
ax[1].set_title("Immagine 2")
ax[1].axis("off")

plt.show()
# Out:
# torch.Size([64, 1, 28, 28])
# torch.Size([1, 7, 7])

# %%
# define the NN architecture (similar to the previous one for denoising
# but refined to work on 7x7 input images (only the encoder kernel, stride and padding sizes are changed)
class AE_Upsample(nn.Module):
    def __init__(self, latent_size = 64):
        super(AE_Upsample, self).__init__()
        
        self.latent_size = latent_size
        
        ## encoder ##
        # x.size() = bs, 1, 7, 7 -> bs, latent_size
        self.Encoder = nn.Sequential(nn.Conv2d(1, 16, 2, stride = 2, padding=1), #16x4x4   [(W−K+2P)/S]+1
                                        nn.ReLU(),
                                        nn.Conv2d(16, 32, 2, stride = 2, padding=1), #64x3x3
                                        nn.ReLU(),
                                        nn.Conv2d(32, 64, 3, stride = 2, padding=1), #64x2x2
                                        nn.ReLU(),
                                        nn.Conv2d(64, self.latent_size, 2, stride = 1, padding=0), #64x1x1
                                        nn.ReLU(), 
                                        nn.Flatten())  #latent_size
        
        ## decoder ##
        # x.size() = bs, latent_size, 1, 1 -> bs, 1, 7, 7
        self.Decoder = nn.Sequential(nn.ConvTranspose2d( self.latent_size, 64, 4, 1, 0), #4x4  (W - 1)S -2P + (K - 1) + 1
                                    nn.ReLU(),
                                    nn.ConvTranspose2d( 64, 32, 3, 2, 1), #7x7
                                    nn.ReLU(),
                                    nn.ConvTranspose2d( 32, 16, 4, 2, 1), #14x14
                                    nn.ReLU(),
                                    nn.ConvTranspose2d( 16, 1, 4, 2, 1), #28x28
                                    nn.Sigmoid())


    def forward(self, x):
        ## encode ##
        latent = self.Encoder(x)  # compressed representation
        
        ## decode ##
        x = self.Decoder(latent.view(x.size(0),self.latent_size,1,1))
        
        return x, latent

    
aeU = AE_Upsample().to(device)
print(aeU)
# Out:
# AE_Upsample(
#   (Encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(2, 2), stride=(2, 2), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(16, 32, kernel_size=(2, 2), stride=(2, 2), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(64, 64, kernel_size=(2, 2), stride=(1, 1))
#     (7): ReLU()
#     (8): Flatten(start_dim=1, end_dim=-1)
#   )
#   (Decoder): Sequential(
#     (0): ConvTranspose2d(64, 64, kernel_size=(4, 4), stride=(1, 1))
#     (1): ReLU()
#     (2): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): ReLU()
#     (4): ConvTranspose2d(32, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (5): ReLU()
#     (6): ConvTranspose2d(16, 1, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (7): Sigmoid()
#   )
# )

# %%
# define Optimizer and Loss
optimizer = torch.optim.Adam(aeU.parameters(), lr=0.001)

# as loss lets use MSE
mse_loss = nn.MSELoss()

# %%
# TRAIN!!!

aeU.train()

for epoch in range(3):
    for batch_idx, (data, target) in enumerate(train_loader):
        # send to device
        data = data.to(device)
        
        # add noise pixels
        downsample_image = torch.nn.functional.interpolate(data, size = [7,7], mode='bilinear', align_corners=False, antialias=True)
        
        optimizer.zero_grad()
        output, latent = aeU(downsample_image)
        # loss between the output of AE and original data withoud noise
        loss = mse_loss(output, data)
        loss.backward()
        optimizer.step()
        if batch_idx % 200 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
    
    #torch.save(ae.state_dict(), "./res/ae.pth")
# Out:
# Train Epoch: 0 [0/60000 (0%)]	Loss: 0.199577
# Train Epoch: 0 [12800/60000 (21%)]	Loss: 0.063928
# Train Epoch: 0 [25600/60000 (43%)]	Loss: 0.051673
# Train Epoch: 0 [38400/60000 (64%)]	Loss: 0.044358
# Train Epoch: 0 [51200/60000 (85%)]	Loss: 0.034769
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.033552
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.029750
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.024798
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.025351
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.025666
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.023405
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.019886
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.017180
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.018689
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.018257

# %%
# if you want to save the model
PATH = './res/AE_Upsample.pth'
torch.save(aeU.state_dict(), PATH)

# %%
# if you want to load the model
PATH = './res/AE_Upsample.pth'
aeU.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %%
# TEST
image, target = next(iter(test_loader)) # load one batch
image = image.to(device)
downsample_image = torch.nn.functional.interpolate(image, size = [7,7], mode='bilinear', align_corners=False, antialias=True)

aeU.eval()
with torch.no_grad():
    output, latent = aeU(downsample_image)

# %%
image_grid = torchvision.utils.make_grid(image[:8])
plt.imshow(to_pil(image_grid))
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(241.5), np.float64(31.5), np.float64(-0.5))

# %%
image_grid = torchvision.utils.make_grid(downsample_image[:8])
plt.imshow(to_pil(image_grid))
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(73.5), np.float64(10.5), np.float64(-0.5))

# %%
image_grid = torchvision.utils.make_grid(output[:8])
plt.imshow(to_pil(image_grid))
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(241.5), np.float64(31.5), np.float64(-0.5))

# %%
# Let's visualize latent space
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2).fit_transform(latent.detach().cpu().numpy())

# %%
print(tsne.shape, target.shape)
# Out:
# (1000, 2) torch.Size([1000])

# %%
# plot
# scale and move the coordinates so they fit [-1; 1] range
def scale_to_01_range(x):
    # compute the distribution range
    value_range = (np.max(x) - np.min(x))

    # move the distribution so that it starts from zero
    # by extracting the minimal value from all its values
    starts_from_zero = x - np.min(x)

    # make the distribution fit [-1; 1] by dividing by its range
    return 2*(starts_from_zero / value_range) - 1

# extract x and y coordinates representing the positions of the images on T-SNE plot
tx = tsne[:, 0]
ty = tsne[:, 1]

tx = scale_to_01_range(tx)
ty = scale_to_01_range(ty)

tsne[:, 0] = tx
tsne[:, 1] = ty

plot_data_np(tsne, target.numpy(), legend = True)
